# %% [markdown]
# # The problem about ollama it's because it does not works well in at windows system

# %%
from ollama import chat

response = chat(
    model='glm-4.7:cloud',
    messages=[{'role': 'user', 'content': 'Hello!'}],
)
print(response.message.content)
# Out:
# Hello! I'm GLM, trained by Z.ai. How can I assist you today? Whether you have questions or just want to chat, I'm happy to help.
